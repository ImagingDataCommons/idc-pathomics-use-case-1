# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Dummy algorithm

# %% [markdown]
# This algorithm does nothing during training and predicts random values. The purpose of this notebook is to demonstrate the processing pipeline.

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# Original svs-files and a json-file with metadata are located at ?. This step produces patches from the images and metadata-files for the experiment.

# %%
from data.tile_generation import run_tile_generation

#run_tile_generation('/input_data/slides', '/output_data/tiles')
# Out:
# Reading input data from /input_data/slides
# Slide TCGA-43-8115-01A-01-BS1.9ddf5647-9e2b-4f20-b6f6-4e22bb7798a8 already tiled
# Slide TCGA-55-A57B-01A-01-TS1.470598E9-1F33-4D37-8C93-21876A8C5F96 already tiled
# Slide TCGA-18-4083-01A-01-TS1.a0388938-dc73-4298-9e5a-b4db390cdff4 already tiled
# Slide TCGA-63-7023-01A-01-BS1.cf277f61-7e00-476e-9e1b-820dc885cf51 already tiled
# Slide TCGA-55-8514-01A-01-TS1.0e0f5cf3-96e9-4a35-aaed-4340df78d389 already tiled
# Sorting NORMAL vs. CANCER

# %%
from data.tile_sorting import run_tile_sorting

#run_tile_sorting('/output/tiles', '/input/slides/metadata.cart.2017-03-02T00_36_30.276824.json', 
#                 '/output_data', 1)
#run_tile_sorting('/output/tiles', '/input/slides/metadata.cart.2017-03-02T00_36_30.276824.json',
#                 '/output', 2)
run_tile_sorting('/output/tiles', '/input/slides/metadata.cart.2017-03-02T00_36_30.276824.json',
                 '/output', 3)

# %% [markdown]
# ## Model training

# %%
#from data.data_set import Dataset
#from model.dummy_model import DummyModel
#from model.inceptionv3_model import InceptionModel

#dataset = Dataset('/output/csv_train.csv', num_classes=2)
#model = DummyModel(shape=(512, 512, 3))
#model = InceptionModel(num_classes=2)
#print(model)

#model.train(dataset, batch_size=4, epochs=2) #, validation_dataset=dataset)

#model.save('/output/trained_model')

# some prediction
#data_point = dataset.data_points[0]
#prediction = model.predict(data_point)
#print('prediction on some sample: %f (reference is %d)' % (prediction, data_point.get_reference_value()))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 510, 510, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 255, 255, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 253, 253, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 126, 126, 64)      0
# _________________________________________________________________
# flatten (Flatten)            (None, 1016064)           0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 1016065
# ...
# Total params: 1,035,457
# Trainable params: 1,035,457
# Non-trainable params: 0
# ...

# %% [markdown]
# ## Evaluation

# %% [markdown]
# The test data set is used to perform slide-based evaluation of the trained model. Results are presented as ROC-Curves and ROC-AUC values for two different ways of aggregating the patch-wise prediction into slide-wise predictions.

# %%
#import matplotlib.pyplot as plt
#from data.data_set import Dataset
#from evaluation.evaluation import per_slide_evaluation
#from evaluation.roc import evaluate_by_roc_curve

#test_dataset = Dataset('/output/csv_train.csv', num_classes=2)

#result_df = per_slide_evaluation(model, test_dataset)
#fig = plt.figure(figsize=(10, 7))
#evaluate_by_roc_curve(fig, result_df)
#plt.show()
# Out:
# res [nan nan] [0. 1.] nan
# res [nan nan] [0. 1.] nan
# res [nan nan] [0. 1.] nan
